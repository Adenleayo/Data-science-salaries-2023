# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
ds_salaries = pd.read_csv("C:\\Users\\Adenle\\Desktop\\DS projects\\ds_salaries\\ds_salaries.csv")
ds_salaries.head(5)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
ds_salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
ds_salaries['job_title'].unique()
# Out:
# array(['Data Scientist', 'Machine Learning Scientist',
#        'Big Data Engineer', 'Product Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst', 'Lead Data Scientist',
#        'Business Data Analyst', 'Lead Data Engineer', 'Lead Data Analyst',
#        'Data Engineer', 'Data Science Consultant', 'BI Data Analyst',
#        'Director of Data Science', 'Research Scientist',
#        'Machine Learning Manager', 'Data Engineering Manager',
#        'Machine Learning Infrastructure Engineer', 'ML Engineer',
#        'AI Scientist', 'Computer Vision Engineer',
#        'Principal Data Scientist', 'Data Science Manager', 'Head of Data',
#        '3D Computer Vision Researcher', 'Data Analytics Engineer',
#        'Applied Data Scientist', 'Marketing Data Analyst',
#        'Cloud Data Engineer', 'Financial Data Analyst',
#        'Computer Vision Software Engineer',
#        'Director of Data Engineering', 'Data Science Engineer',
# ...

# %%
ds_salaries.shape
# Out:
# (607, 12)

# %%
ds_salaries = ds_salaries.drop('Unnamed: 0',axis=1)
ds_salaries
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
ds_salaries['company_location'].unique()
# Out:
# array(['DE', 'JP', 'GB', 'HN', 'US', 'HU', 'NZ', 'FR', 'IN', 'PK', 'CN',
#        'GR', 'AE', 'NL', 'MX', 'CA', 'AT', 'NG', 'ES', 'PT', 'DK', 'IT',
#        'HR', 'LU', 'PL', 'SG', 'RO', 'IQ', 'BR', 'BE', 'UA', 'IL', 'RU',
#        'MT', 'CL', 'IR', 'CO', 'MD', 'KE', 'SI', 'CH', 'VN', 'AS', 'TR',
#        'CZ', 'DZ', 'EE', 'MY', 'AU', 'IE'], dtype=object)

# %%
ds_salaries[ds_salaries['employee_residence'] == 'NG'] [['salary','employee_residence']]
# Out:
#      salary employee_residence
# 38    10000                 NG
# 116   50000                 NG

# %%
ds_salaries.describe().transpose()
# Out:
#                count           mean           std     min      25%       50%  \
# work_year      607.0    2021.405272  6.921330e-01  2020.0   2021.0    2022.0
# salary         607.0  324000.062603  1.544357e+06  4000.0  70000.0  115000.0
# salary_in_usd  607.0  112297.869852  7.095726e+04  2859.0  62726.0  101570.0
# remote_ratio   607.0      70.922570  4.070913e+01     0.0     50.0     100.0
#
#                     75%         max
# work_year        2022.0      2022.0
# salary         165000.0  30400000.0
# salary_in_usd  150000.0    600000.0
# remote_ratio      100.0       100.0

# %%
ds_salaries.groupby('job_title').mean().round(2) ['salary']
# Out:
# job_title
# 3D Computer Vision Researcher                400000.00
# AI Scientist                                 290571.43
# Analytics Engineer                           175000.00
# Applied Data Scientist                       172400.00
# Applied Machine Learning Scientist           141350.00
# BI Data Analyst                             1902045.33
# Big Data Architect                           125000.00
# Big Data Engineer                            455000.00
# Business Data Analyst                        355000.00
# Cloud Data Engineer                          140000.00
# Computer Vision Engineer                      83500.00
# Computer Vision Software Engineer            100333.33
# Data Analyst                                  96604.96
# Data Analytics Engineer                       61750.00
# Data Analytics Lead                          405000.00
# Data Analytics Manager                       127134.29
# Data Architect                               177873.91
# ...

# %%
ds_salaries = ds_salaries.set_index(['job_title','employee_residence'])  #[['salary_currency','salary']]

# %%
ds_salaries.head()
# Out:
#                                                work_year experience_level  \
# job_title                  employee_residence
# Data Scientist             DE                       2020               MI
# Machine Learning Scientist JP                       2020               SE
# Big Data Engineer          GB                       2020               SE
# Product Data Analyst       HN                       2020               MI
# Machine Learning Engineer  US                       2020               SE
#
#                                               employment_type  salary  \
# job_title                  employee_residence
# Data Scientist             DE                              FT   70000
# Machine Learning Scientist JP                              FT  260000
# Big Data Engineer          GB                              FT   85000
# Product Data Analyst       HN                              FT   20000
# Machine Learning Engineer  US                              FT  150000
#
# ...

# %%
ds_salaries['$Exchange_rate'] = ds_salaries['']
